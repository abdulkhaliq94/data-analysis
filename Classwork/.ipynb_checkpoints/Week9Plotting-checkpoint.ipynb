# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_rows', 500)

# %%
values = np.array([
    [100, 80, 95],
    [55, 60, 45],
    [70, 75, 90],
    [75, 70, 60],
    [60, 73, 75],
    [72, 63, 70]
])
df = pd.DataFrame(values,
                   columns=['Midterm', 'Project', 'Final'],
                   index=['Alex', 'Bob', 'Chris', 'Doug', 'Eva', "Frank"])
df
# Out:
#        Midterm  Project  Final
# Alex       100       80     95
# Bob         55       60     45
# Chris       70       75     90
# Doug        75       70     60
# Eva         60       73     75
# Frank       72       63     70

# %%
data = pd.read_csv("../../Data/houseprices/train.csv", delimiter=",")
data.head().T
# Out:
#                      0        1        2        3        4
# Id                   1        2        3        4        5
# MSSubClass          60       20       60       70       60
# MSZoning            RL       RL       RL       RL       RL
# LotFrontage         65       80       68       60       84
# LotArea           8450     9600    11250     9550    14260
# Street            Pave     Pave     Pave     Pave     Pave
# Alley              NaN      NaN      NaN      NaN      NaN
# LotShape           Reg      Reg      IR1      IR1      IR1
# LandContour        Lvl      Lvl      Lvl      Lvl      Lvl
# Utilities       AllPub   AllPub   AllPub   AllPub   AllPub
# LotConfig       Inside      FR2   Inside   Corner      FR2
# LandSlope          Gtl      Gtl      Gtl      Gtl      Gtl
# Neighborhood   CollgCr  Veenker  CollgCr  Crawfor  NoRidge
# Condition1        Norm    Feedr     Norm     Norm     Norm
# Condition2        Norm     Norm     Norm     Norm     Norm
# ...

# %%
# Plotting with Pandas

# %%
# Line plot of YrSold
sorted_YrSold = data['YrSold'].sort_values().reset_index(drop=True)
# sorted_YrSold
sorted_YrSold.plot()

# %%
# df.plot(use_index=False)
df.plot(rot=90,
        grid=True)

# %%
# Line plot with xticks, xlim
sorted_YrSold.plot(xticks=[0, 500, 1000, 1500],
                   xlim=[500, 1000])

# %% [markdown]
# Pandas plot arguments:
# - label
# - ax
# - style
# - alpha
# - kind
# - logy
# - use_index
# - rot
# - xticks
# - yticks
# - xlim
# - ylim
# - grid

# %%
sorted_YrSold.plot(label="Year Sold", legend=True,
                   style='-.',
                   alpha=0.5,
                   kind='line',
                   logy=False,
                   use_index=True,
                   )

# %% [markdown]
# Multiple plot arguments
# - subplots
# - sharex
# - sharey
# - figsize
# - title
# - legend
# - sort_columns

# %%
# Plot grade data separatedly with shared x axis
df.plot(subplots=True,
        figsize=(5, 15),
        sharex=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000182A014E908>,
# ...
#       dtype=object)

# %%
# Bar plots on GarageCars
# data['GarageCars'].value_counts().plot(kind='bar')
# data['GarageCars'].value_counts().sort_index().plot(kind='bar')
freq_garagecars = data['GarageCars'].value_counts().sort_index()
freq_garagecars.plot(kind='bar')
freq_garagecars
# Out:
# 0     81
# 1    369
# 2    824
# 3    181
# 4      5
# Name: GarageCars, dtype: int64

# %%
# Horizontal bar plots on GarageType
freq_garagecars.plot.barh()

# %%
# Bar plot on multiple features: ['TotalBsmtSF', '1stFlrSF', '2ndFlrSF']
cols = ['TotalBsmtSF', '1stFlrSF', '2ndFlrSF']
subdata= data.loc[:10, cols]
subdata.plot.bar(figsize=(15, 5))

# %%
# Stacked bar chart
subdata.plot.barh(stacked=True)

# %%
# histogram of 1stFlrSF
data['1stFlrSF'].plot.hist(bins=100)
# data['1stFlrSF'].plot(kind='hist')
# plt.hist(data['1stFlrSF'])

# %%
# Density plot of 1stFlrSF
data['1stFlrSF'].plot.density(xlim=(0, 5000))

# %%
data['Heating'].value_counts()
# Out:
# GasA     1428
# GasW       18
# Grav        7
# Wall        4
# OthW        2
# Floor       1
# Name: Heating, dtype: int64

# %%
data['Heating'].value_counts().plot.pie(figsize=(10, 10))

# %% [markdown]
# ## II. Plot with seaborn
# If matplotlib tries to make easy things easy and hard things possible, seaborn tries to make hard things easy too.

# %%
import seaborn as sns
# Swarm plot
plt.figure(figsize=(20, 10))
subdata = data[['BedroomAbvGr', 'SalePrice']]
sns.swarmplot(x="BedroomAbvGr", y="SalePrice", data=subdata)

# %%
# Bar plot
# HouseStyle, BedroomAbvGr vs. SalePrice
sns.catplot("HouseStyle", "SalePrice", "BedroomAbvGr", data=data, kind="bar",
            height=10, aspect=1)

# %%
# Extract houses with 2 - 3 floor bedrooms
index1 = (data['BedroomAbvGr'] >= 2) & (data['BedroomAbvGr'] <= 4)
index2 = (data['HouseStyle'] == '1Story') | (data['HouseStyle'] == '2Story')
subdata = data[index1 & index2]
subdata.shape
# Out:
# (1113, 81)

# %%
sns.catplot('HouseStyle', 'SalePrice', 'BedroomAbvGr', data=subdata, kind='bar')

# %%
plt.scatter(data['GrLivArea'] , data['SalePrice'])

# %%
sns.regplot('GrLivArea', 'SalePrice', data=data)

# %%
# box plot
sns.catplot('Fireplaces', 'SalePrice', kind='box', data=data)
